# %%
#Cell 1

import os
import shutil
import zipfile
import warnings
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
from google.colab import drive

warnings.filterwarnings('ignore')
print("Imports successful.")
# Out:
# Imports successful.

# %%
#Cell 2

GDRIVE_ZIP_PATH = '/content/drive/MyDrive/AD_Dataset_compressed.zip'
LOCAL_ZIP_PATH = '/content/Data.zip'
LOCAL_UNZIP_DIR = '/content/Data'
DATA_DIR = '/content/Data/AD Datasets/Data'

IMG_SIZE = (224, 224)
BATCH_SIZE = 128
NUM_CLASSES = 4
EPOCHS = 100
LEARNING_RATE = 1e-4
SEED = 42
BEST_MODEL_SAVE_PATH = 'resnet50_best_model.keras'
AUTOTUNE = tf.data.AUTOTUNE

print("Configuration parameters set.")
# Out:
# Configuration parameters set.

# %%
# Cell 3: Mount Google Drive & Extract Dataset

drive.mount('/content/drive', force_remount=True)

if not os.path.exists(GDRIVE_ZIP_PATH):
    raise FileNotFoundError(f"Zip file not found at {GDRIVE_ZIP_PATH}")

shutil.copyfile(GDRIVE_ZIP_PATH, LOCAL_ZIP_PATH)

if os.path.exists(LOCAL_UNZIP_DIR):
    shutil.rmtree(LOCAL_UNZIP_DIR)
os.makedirs(LOCAL_UNZIP_DIR)

with zipfile.ZipFile(LOCAL_ZIP_PATH, 'r') as z:
    z.extractall(LOCAL_UNZIP_DIR)

if not os.path.isdir(DATA_DIR):
    raise FileNotFoundError(f"Expected data directory not found at {DATA_DIR}")

print("Dataset successfully extracted.")
# Out:
# Mounted at /content/drive
# Dataset successfully extracted.

# %%
#Cell 4:  Load Dataset & Split (80/10/10)


full_dataset = image_dataset_from_directory(
    DATA_DIR,
    label_mode='int',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

class_names = full_dataset.class_names
print("Classes:", class_names)

total_batches = tf.data.experimental.cardinality(full_dataset).numpy()
train_batches = int(total_batches * 0.8)
val_batches = int(total_batches * 0.1)
test_batches = total_batches - train_batches - val_batches

if val_batches == 0 and total_batches > train_batches:
    val_batches = 1
if test_batches == 0 and total_batches > train_batches + val_batches:
    test_batches = 1
train_batches = total_batches - val_batches - test_batches

train_dataset = full_dataset.take(train_batches)
val_and_test = full_dataset.skip(train_batches)
val_dataset = val_and_test.take(val_batches)
test_dataset = val_and_test.skip(val_batches)

print(f"Total batches: {total_batches}; train: {train_batches}; val: {val_batches}; test: {test_batches}")
# Out:
# Found 86437 files belonging to 4 classes.
# Classes: ['Mild Dementia', 'Moderate Dementia', 'Non Demented', 'Very mild Dementia']
# Total batches: 676; train: 540; val: 67; test: 69

# %%
# Cell 5: Class Weights, Caching, and Augmentation


train_label_list = []
for _, lbl in train_dataset:
    train_label_list.extend(lbl.numpy())
train_label_array = np.array(train_label_list)

unique_classes = np.unique(train_label_array)
weights = compute_class_weight('balanced', classes=unique_classes, y=train_label_array)
class_weight_dict = {int(c): float(w) for c, w in zip(unique_classes, weights)}
print("Class weights:", class_weight_dict)

train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.15),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomContrast(0.15),
])

print("Augmentation and caching configured.")
# Out:
# Class weights: {0: 4.3680485338725985, 1: 45.23560209424084, 2: 0.32106426859404325, 3: 1.5764984946628957}
# Augmentation and caching configured.

# %%
#Cell 6

import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model

# --- Define Focal Loss ---
def focal_loss_fn(alpha=0.25, gamma=2.5):
    def focal_loss(y_true, y_pred):
        y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=NUM_CLASSES)
        y_pred = tf.clip_by_value(y_pred, 1e-8, 1.0 - 1e-8)
        cross_entropy = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        loss = tf.reduce_sum(weight * cross_entropy, axis=1)
        return tf.reduce_mean(loss)
    return focal_loss

# --- Base Model (Frozen) ---
base_model = ResNet50(
    weights= None,
    include_top=False,
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)
base_model.trainable = True  # keep frozen for transfer learning

# --- Build Custom Head ---
inputs = tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = data_augmentation(inputs)
x = tf.keras.applications.resnet50.preprocess_input(x)
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)

x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(1024 * 2, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(1024 * 4, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(1024 * 2, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(256, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(10, activation='relu')(x)

outputs = Dense(NUM_CLASSES, activation='softmax')(x)
model = Model(inputs, outputs)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 224, 224,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 224, 224,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 7, 7,      │ 23,587,712 │ add[0][0]         │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1024)      │  2,098,176 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1024)      │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 2048)      │  2,099,200 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 2048)      │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4096)      │  8,392,704 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 4096)      │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 2048)      │  8,390,656 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 2048)      │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1024)      │  2,098,176 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 1024)      │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │    262,400 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 256)       │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 10)        │      2,570 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 4)         │         44 │ dense_6[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 46,931,638 (179.03 MB)
#  Trainable params: 46,878,518 (178.83 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
# --- Recompute class weights from training dataset ---
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

print("Recomputing class weights...")

# Collect labels from the training dataset
train_labels = []
for _, labels in train_dataset:
    train_labels.extend(labels.numpy())
train_labels = np.array(train_labels)

# Compute balanced class weights
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_labels),
    y=train_labels
)

# Map weights to each class index
class_weight_dict_mapped = {int(cls): float(w) for cls, w in zip(np.unique(train_labels), class_weights_array)}

print("Computed class weights:", class_weight_dict_mapped)
# Out:
# Recomputing class weights...
# Computed class weights: {0: 4.35374149659864, 1: 45.354330708661415, 2: 0.3210463733650416, 3: 1.578658870820391}

# %%
#Cell 7
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# --- Compile Model with Focal Loss ---
optimizer = Adam(learning_rate=1e-5)
model.compile(optimizer=optimizer, loss=focal_loss_fn(alpha=0.25, gamma=2.5), metrics=['accuracy'])

# --- Checkpoint (monitor val_loss) ---
checkpoint = ModelCheckpoint(
    filepath=BEST_MODEL_SAVE_PATH,
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# --- Early Stopping ---
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# --- Train the Model ---
EPOCHS = 100
print(f"\n--- Starting Model Training ({EPOCHS} Epochs) ---")
print(f"Best model will be saved to {BEST_MODEL_SAVE_PATH}")

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    class_weight=class_weight_dict_mapped,
    callbacks=[checkpoint]
)

print("\n--- Training Complete ---")

model.save('/content/drive/MyDrive/resnet50_best_model.keras')
# Out:
# --- Starting Model Training (100 Epochs) ---
# Best model will be saved to resnet50_best_model.keras
# Epoch 1/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.6697 - loss: 0.0833
# Epoch 1: val_loss improved from inf to 0.06288, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 244s 371ms/step - accuracy: 0.6698 - loss: 0.0833 - val_accuracy: 0.7695 - val_loss: 0.0629
# Epoch 2/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7781 - loss: 0.0651
# Epoch 2: val_loss improved from 0.06288 to 0.06177, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 345ms/step - accuracy: 0.7781 - loss: 0.0651 - val_accuracy: 0.7695 - val_loss: 0.0618
# Epoch 3/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7799 - loss: 0.0598
# Epoch 3: val_loss improved from 0.06177 to 0.06091, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.7799 - loss: 0.0598 - val_accuracy: 0.7695 - val_loss: 0.0609
# Epoch 4/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7790 - loss: 0.0532
# Epoch 4: val_loss improved from 0.06091 to 0.05965, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 345ms/step - accuracy: 0.7789 - loss: 0.0532 - val_accuracy: 0.7410 - val_loss: 0.0596
# Epoch 5/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7792 - loss: 0.0514
# Epoch 5: val_loss did not improve from 0.05965
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.7792 - loss: 0.0514 - val_accuracy: 0.7067 - val_loss: 0.0641
# Epoch 6/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7814 - loss: 0.0499
# Epoch 6: val_loss improved from 0.05965 to 0.05771, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.7814 - loss: 0.0499 - val_accuracy: 0.7452 - val_loss: 0.0577
# Epoch 7/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7839 - loss: 0.0484
# Epoch 7: val_loss did not improve from 0.05771
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.7839 - loss: 0.0484 - val_accuracy: 0.7360 - val_loss: 0.0590
# Epoch 8/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7862 - loss: 0.0471
# Epoch 8: val_loss improved from 0.05771 to 0.05381, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.7862 - loss: 0.0471 - val_accuracy: 0.7473 - val_loss: 0.0538
# Epoch 9/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7849 - loss: 0.0463
# Epoch 9: val_loss did not improve from 0.05381
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.7849 - loss: 0.0463 - val_accuracy: 0.7172 - val_loss: 0.0601
# Epoch 10/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7885 - loss: 0.0446
# Epoch 10: val_loss improved from 0.05381 to 0.05186, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.7885 - loss: 0.0446 - val_accuracy: 0.7521 - val_loss: 0.0519
# Epoch 11/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7904 - loss: 0.0435
# Epoch 11: val_loss did not improve from 0.05186
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.7904 - loss: 0.0435 - val_accuracy: 0.7172 - val_loss: 0.0602
# Epoch 12/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7953 - loss: 0.0422
# Epoch 12: val_loss did not improve from 0.05186
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.7953 - loss: 0.0422 - val_accuracy: 0.7389 - val_loss: 0.0539
# Epoch 13/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7980 - loss: 0.0411
# Epoch 13: val_loss improved from 0.05186 to 0.04717, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.7980 - loss: 0.0411 - val_accuracy: 0.7653 - val_loss: 0.0472
# Epoch 14/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7990 - loss: 0.0408
# Epoch 14: val_loss improved from 0.04717 to 0.04548, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.7990 - loss: 0.0408 - val_accuracy: 0.7723 - val_loss: 0.0455
# Epoch 15/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8008 - loss: 0.0394
# Epoch 15: val_loss improved from 0.04548 to 0.04118, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.8008 - loss: 0.0394 - val_accuracy: 0.7857 - val_loss: 0.0412
# Epoch 16/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8061 - loss: 0.0381
# Epoch 16: val_loss did not improve from 0.04118
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8061 - loss: 0.0381 - val_accuracy: 0.7402 - val_loss: 0.0487
# Epoch 17/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8074 - loss: 0.0373
# Epoch 17: val_loss did not improve from 0.04118
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8074 - loss: 0.0373 - val_accuracy: 0.7641 - val_loss: 0.0484
# Epoch 18/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8084 - loss: 0.0362
# Epoch 18: val_loss improved from 0.04118 to 0.03303, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.8084 - loss: 0.0362 - val_accuracy: 0.8052 - val_loss: 0.0330
# Epoch 19/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8112 - loss: 0.0351
# Epoch 19: val_loss did not improve from 0.03303
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8112 - loss: 0.0351 - val_accuracy: 0.8018 - val_loss: 0.0350
# Epoch 20/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8170 - loss: 0.0342
# Epoch 20: val_loss did not improve from 0.03303
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8170 - loss: 0.0342 - val_accuracy: 0.7768 - val_loss: 0.0467
# Epoch 21/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8179 - loss: 0.0335
# Epoch 21: val_loss did not improve from 0.03303
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8179 - loss: 0.0335 - val_accuracy: 0.7955 - val_loss: 0.0460
# Epoch 22/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8233 - loss: 0.0325
# Epoch 22: val_loss did not improve from 0.03303
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8233 - loss: 0.0325 - val_accuracy: 0.7908 - val_loss: 0.0403
# Epoch 23/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8267 - loss: 0.0314
# Epoch 23: val_loss did not improve from 0.03303
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8267 - loss: 0.0314 - val_accuracy: 0.7928 - val_loss: 0.0395
# Epoch 24/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8303 - loss: 0.0304
# Epoch 24: val_loss did not improve from 0.03303
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8303 - loss: 0.0304 - val_accuracy: 0.7840 - val_loss: 0.0409
# Epoch 25/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8340 - loss: 0.0291
# Epoch 25: val_loss did not improve from 0.03303
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8340 - loss: 0.0291 - val_accuracy: 0.7676 - val_loss: 0.0387
# Epoch 26/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8382 - loss: 0.0282
# Epoch 26: val_loss improved from 0.03303 to 0.03288, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.8382 - loss: 0.0282 - val_accuracy: 0.8068 - val_loss: 0.0329
# Epoch 27/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8398 - loss: 0.0273
# Epoch 27: val_loss did not improve from 0.03288
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8398 - loss: 0.0273 - val_accuracy: 0.7930 - val_loss: 0.0395
# Epoch 28/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8433 - loss: 0.0263
# Epoch 28: val_loss did not improve from 0.03288
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8433 - loss: 0.0263 - val_accuracy: 0.7810 - val_loss: 0.0650
# Epoch 29/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8514 - loss: 0.0252
# Epoch 29: val_loss improved from 0.03288 to 0.02516, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.8514 - loss: 0.0252 - val_accuracy: 0.8524 - val_loss: 0.0252
# Epoch 30/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8534 - loss: 0.0247
# Epoch 30: val_loss did not improve from 0.02516
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8534 - loss: 0.0247 - val_accuracy: 0.8340 - val_loss: 0.0352
# Epoch 31/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8561 - loss: 0.0237
# Epoch 31: val_loss did not improve from 0.02516
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8560 - loss: 0.0237 - val_accuracy: 0.7795 - val_loss: 0.0444
# Epoch 32/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8589 - loss: 0.0231
# Epoch 32: val_loss improved from 0.02516 to 0.02321, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.8589 - loss: 0.0231 - val_accuracy: 0.8632 - val_loss: 0.0232
# Epoch 33/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8648 - loss: 0.0220
# Epoch 33: val_loss did not improve from 0.02321
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8648 - loss: 0.0220 - val_accuracy: 0.7956 - val_loss: 0.0334
# Epoch 34/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8671 - loss: 0.0214
# Epoch 34: val_loss did not improve from 0.02321
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8671 - loss: 0.0214 - val_accuracy: 0.8425 - val_loss: 0.0298
# Epoch 35/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8728 - loss: 0.0200
# Epoch 35: val_loss did not improve from 0.02321
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8728 - loss: 0.0200 - val_accuracy: 0.8251 - val_loss: 0.0424
# Epoch 36/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8775 - loss: 0.0189
# Epoch 36: val_loss improved from 0.02321 to 0.02283, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.8775 - loss: 0.0189 - val_accuracy: 0.8680 - val_loss: 0.0228
# Epoch 37/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8809 - loss: 0.0183
# Epoch 37: val_loss improved from 0.02283 to 0.01977, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.8809 - loss: 0.0183 - val_accuracy: 0.8686 - val_loss: 0.0198
# Epoch 38/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8831 - loss: 0.0175
# Epoch 38: val_loss did not improve from 0.01977
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8831 - loss: 0.0175 - val_accuracy: 0.8505 - val_loss: 0.0334
# Epoch 39/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8883 - loss: 0.0169
# Epoch 39: val_loss did not improve from 0.01977
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8883 - loss: 0.0169 - val_accuracy: 0.8626 - val_loss: 0.0273
# Epoch 40/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8918 - loss: 0.0168
# Epoch 40: val_loss did not improve from 0.01977
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8918 - loss: 0.0168 - val_accuracy: 0.8736 - val_loss: 0.0236
# Epoch 41/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8958 - loss: 0.0156
# Epoch 41: val_loss did not improve from 0.01977
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8958 - loss: 0.0156 - val_accuracy: 0.8375 - val_loss: 0.0352
# Epoch 42/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8993 - loss: 0.0151
# Epoch 42: val_loss did not improve from 0.01977
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8993 - loss: 0.0151 - val_accuracy: 0.8645 - val_loss: 0.0224
# Epoch 43/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9075 - loss: 0.0141
# Epoch 43: val_loss improved from 0.01977 to 0.01751, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.9075 - loss: 0.0141 - val_accuracy: 0.8867 - val_loss: 0.0175
# Epoch 44/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9114 - loss: 0.0130
# Epoch 44: val_loss did not improve from 0.01751
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9114 - loss: 0.0130 - val_accuracy: 0.8660 - val_loss: 0.0232
# Epoch 45/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9127 - loss: 0.0126
# Epoch 45: val_loss did not improve from 0.01751
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9127 - loss: 0.0126 - val_accuracy: 0.8656 - val_loss: 0.0288
# Epoch 46/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9180 - loss: 0.0121
# Epoch 46: val_loss improved from 0.01751 to 0.01690, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.9180 - loss: 0.0121 - val_accuracy: 0.9022 - val_loss: 0.0169
# Epoch 47/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9189 - loss: 0.0119
# Epoch 47: val_loss did not improve from 0.01690
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9189 - loss: 0.0119 - val_accuracy: 0.8769 - val_loss: 0.0285
# Epoch 48/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9227 - loss: 0.0121
# Epoch 48: val_loss did not improve from 0.01690
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9227 - loss: 0.0121 - val_accuracy: 0.8944 - val_loss: 0.0169
# Epoch 49/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9278 - loss: 0.0104
# Epoch 49: val_loss improved from 0.01690 to 0.01589, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.9278 - loss: 0.0104 - val_accuracy: 0.9116 - val_loss: 0.0159
# Epoch 50/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9299 - loss: 0.0104
# Epoch 50: val_loss improved from 0.01589 to 0.01477, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.9299 - loss: 0.0104 - val_accuracy: 0.9158 - val_loss: 0.0148
# Epoch 51/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9326 - loss: 0.0097
# Epoch 51: val_loss did not improve from 0.01477
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9326 - loss: 0.0097 - val_accuracy: 0.9117 - val_loss: 0.0152
# Epoch 52/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9379 - loss: 0.0092
# Epoch 52: val_loss did not improve from 0.01477
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9379 - loss: 0.0092 - val_accuracy: 0.8616 - val_loss: 0.0490
# Epoch 53/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9394 - loss: 0.0087
# Epoch 53: val_loss did not improve from 0.01477
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9394 - loss: 0.0087 - val_accuracy: 0.9010 - val_loss: 0.0204
# Epoch 54/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9434 - loss: 0.0083
# Epoch 54: val_loss did not improve from 0.01477
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9434 - loss: 0.0083 - val_accuracy: 0.8531 - val_loss: 0.0544
# Epoch 55/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9470 - loss: 0.0077
# Epoch 55: val_loss did not improve from 0.01477
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9470 - loss: 0.0077 - val_accuracy: 0.9079 - val_loss: 0.0216
# Epoch 56/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9468 - loss: 0.0076
# Epoch 56: val_loss did not improve from 0.01477
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9468 - loss: 0.0076 - val_accuracy: 0.8531 - val_loss: 0.0684
# Epoch 57/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9452 - loss: 0.0081
# Epoch 57: val_loss improved from 0.01477 to 0.01217, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.9452 - loss: 0.0081 - val_accuracy: 0.9295 - val_loss: 0.0122
# Epoch 58/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9526 - loss: 0.0068
# Epoch 58: val_loss did not improve from 0.01217
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9526 - loss: 0.0068 - val_accuracy: 0.8976 - val_loss: 0.0289
# Epoch 59/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9544 - loss: 0.0068
# Epoch 59: val_loss did not improve from 0.01217
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9544 - loss: 0.0068 - val_accuracy: 0.8883 - val_loss: 0.0262
# Epoch 60/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9570 - loss: 0.0062
# Epoch 60: val_loss did not improve from 0.01217
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9570 - loss: 0.0062 - val_accuracy: 0.8920 - val_loss: 0.0316
# Epoch 61/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9563 - loss: 0.0064
# Epoch 61: val_loss did not improve from 0.01217
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9563 - loss: 0.0064 - val_accuracy: 0.8425 - val_loss: 0.0676
# Epoch 62/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9589 - loss: 0.0059
# Epoch 62: val_loss improved from 0.01217 to 0.00801, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.9589 - loss: 0.0059 - val_accuracy: 0.9482 - val_loss: 0.0080
# Epoch 63/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9629 - loss: 0.0053
# Epoch 63: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9629 - loss: 0.0053 - val_accuracy: 0.8288 - val_loss: 0.1043
# Epoch 64/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9634 - loss: 0.0053
# Epoch 64: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9634 - loss: 0.0053 - val_accuracy: 0.8714 - val_loss: 0.0484
# Epoch 65/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9638 - loss: 0.0054
# Epoch 65: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9638 - loss: 0.0054 - val_accuracy: 0.8659 - val_loss: 0.0593
# Epoch 66/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9658 - loss: 0.0052
# Epoch 66: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9658 - loss: 0.0052 - val_accuracy: 0.8479 - val_loss: 0.0511
# Epoch 67/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9659 - loss: 0.0052
# Epoch 67: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9659 - loss: 0.0052 - val_accuracy: 0.9429 - val_loss: 0.0105
# Epoch 68/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9690 - loss: 0.0050
# Epoch 68: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9690 - loss: 0.0050 - val_accuracy: 0.9445 - val_loss: 0.0099
# Epoch 69/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9705 - loss: 0.0044
# Epoch 69: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9705 - loss: 0.0044 - val_accuracy: 0.9330 - val_loss: 0.0135
# Epoch 70/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9713 - loss: 0.0043
# Epoch 70: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9713 - loss: 0.0043 - val_accuracy: 0.8212 - val_loss: 0.0860
# Epoch 71/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9732 - loss: 0.0040
# Epoch 71: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9732 - loss: 0.0040 - val_accuracy: 0.8780 - val_loss: 0.0420
# Epoch 72/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9746 - loss: 0.0037
# Epoch 72: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9746 - loss: 0.0037 - val_accuracy: 0.9030 - val_loss: 0.0283
# Epoch 73/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9726 - loss: 0.0040
# Epoch 73: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9726 - loss: 0.0040 - val_accuracy: 0.8970 - val_loss: 0.0257
# Epoch 74/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9747 - loss: 0.0039
# Epoch 74: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9747 - loss: 0.0039 - val_accuracy: 0.9471 - val_loss: 0.0101
# Epoch 75/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9773 - loss: 0.0035
# Epoch 75: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9773 - loss: 0.0035 - val_accuracy: 0.9214 - val_loss: 0.0196
# Epoch 76/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9747 - loss: 0.0037
# Epoch 76: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9747 - loss: 0.0037 - val_accuracy: 0.9125 - val_loss: 0.0195
# Epoch 77/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9782 - loss: 0.0034
# Epoch 77: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9782 - loss: 0.0034 - val_accuracy: 0.8769 - val_loss: 0.0606
# Epoch 78/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9776 - loss: 0.0034
# Epoch 78: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9776 - loss: 0.0034 - val_accuracy: 0.8580 - val_loss: 0.0716
# Epoch 79/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9790 - loss: 0.0031
# Epoch 79: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9790 - loss: 0.0031 - val_accuracy: 0.9146 - val_loss: 0.0227
# Epoch 80/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9796 - loss: 0.0031
# Epoch 80: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9796 - loss: 0.0031 - val_accuracy: 0.9167 - val_loss: 0.0183
# Epoch 81/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9800 - loss: 0.0031
# Epoch 81: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9800 - loss: 0.0031 - val_accuracy: 0.9197 - val_loss: 0.0261
# Epoch 82/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9811 - loss: 0.0032
# Epoch 82: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9811 - loss: 0.0032 - val_accuracy: 0.8454 - val_loss: 0.0779
# Epoch 83/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9812 - loss: 0.0027
# Epoch 83: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9812 - loss: 0.0027 - val_accuracy: 0.8598 - val_loss: 0.0697
# Epoch 84/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9824 - loss: 0.0028
# Epoch 84: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9824 - loss: 0.0028 - val_accuracy: 0.9312 - val_loss: 0.0175
# Epoch 85/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9837 - loss: 0.0025
# Epoch 85: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9837 - loss: 0.0025 - val_accuracy: 0.9395 - val_loss: 0.0132
# Epoch 86/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9839 - loss: 0.0025
# Epoch 86: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9839 - loss: 0.0025 - val_accuracy: 0.9165 - val_loss: 0.0249
# Epoch 87/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9848 - loss: 0.0024
# Epoch 87: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9848 - loss: 0.0024 - val_accuracy: 0.8597 - val_loss: 0.0648
# Epoch 88/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9861 - loss: 0.0022
# Epoch 88: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9861 - loss: 0.0022 - val_accuracy: 0.9489 - val_loss: 0.0095
# Epoch 89/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9838 - loss: 0.0025
# Epoch 89: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9838 - loss: 0.0025 - val_accuracy: 0.8975 - val_loss: 0.0443
# Epoch 90/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9837 - loss: 0.0026
# Epoch 90: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9837 - loss: 0.0026 - val_accuracy: 0.8434 - val_loss: 0.0954
# Epoch 91/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9840 - loss: 0.0024
# Epoch 91: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9840 - loss: 0.0024 - val_accuracy: 0.9173 - val_loss: 0.0211
# Epoch 92/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9849 - loss: 0.0023
# Epoch 92: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9850 - loss: 0.0023 - val_accuracy: 0.9279 - val_loss: 0.0199
# Epoch 93/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9870 - loss: 0.0021
# Epoch 93: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9870 - loss: 0.0021 - val_accuracy: 0.8767 - val_loss: 0.0483
# Epoch 94/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9876 - loss: 0.0018
# Epoch 94: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9876 - loss: 0.0018 - val_accuracy: 0.9290 - val_loss: 0.0195
# Epoch 95/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9881 - loss: 0.0018
# Epoch 95: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9881 - loss: 0.0018 - val_accuracy: 0.8398 - val_loss: 0.0997
# Epoch 96/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9845 - loss: 0.0026
# Epoch 96: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9845 - loss: 0.0026 - val_accuracy: 0.8300 - val_loss: 0.1184
# Epoch 97/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9860 - loss: 0.0023
# Epoch 97: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9860 - loss: 0.0023 - val_accuracy: 0.8722 - val_loss: 0.0704
# Epoch 98/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9882 - loss: 0.0019
# Epoch 98: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9882 - loss: 0.0019 - val_accuracy: 0.8588 - val_loss: 0.0820
# Epoch 99/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9880 - loss: 0.0020
# Epoch 99: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9880 - loss: 0.0020 - val_accuracy: 0.9240 - val_loss: 0.0224
# Epoch 100/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9887 - loss: 0.0018
# Epoch 100: val_loss did not improve from 0.00801
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9887 - loss: 0.0018 - val_accuracy: 0.9403 - val_loss: 0.0137
#
# --- Training Complete ---

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- Load Best Model ---
best_model = tf.keras.models.load_model(BEST_MODEL_SAVE_PATH, custom_objects={'focal_loss': focal_loss_fn()})

# --- Evaluate ---
train_loss, train_acc = best_model.evaluate(train_dataset)
val_loss, val_acc = best_model.evaluate(val_dataset)
test_loss, test_acc = best_model.evaluate(test_dataset)

print("\n--- Final Overall Performance ---")
print(f"Training Accuracy:   {train_acc:.4f}")
print(f"Validation Accuracy: {val_acc:.4f}")
print(f"Test Accuracy:       {test_acc:.4f}")
print(f"Training Loss:   {train_loss:.4f}")
print(f"Validation Loss: {val_loss:.4f}")
print(f"Test Loss:       {test_loss:.4f}")

# --- Predict and Metrics ---
y_true = np.concatenate([y for _, y in test_dataset], axis=0)
y_pred_probs = best_model.predict(test_dataset)
y_pred = np.argmax(y_pred_probs, axis=1)

print("\n--- Per-Class Metrics (Test Set) ---")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# --- Plot Learning Curves ---
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy Curve')

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss Curve')

plt.show()
# Out:
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 41s 70ms/step - accuracy: 0.9517 - loss: 0.0075
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9471 - loss: 0.0080
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 27s 104ms/step - accuracy: 0.9550 - loss: 0.0075
#
# --- Final Overall Performance ---
# Training Accuracy:   0.9514
# Validation Accuracy: 0.9482
# Test Accuracy:       0.9531
# Training Loss:   0.0077
# Validation Loss: 0.0080
# Test Loss:       0.0080
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step
#
# --- Per-Class Metrics (Test Set) ---
#                     precision    recall  f1-score   support
#
#      Mild Dementia     0.9388    0.8812    0.9091       522
#  Moderate Dementia     0.9800    0.9423    0.9608        52
#       Non Demented     0.9694    0.9768    0.9731      6809
# Very mild Dementia     0.8739    0.8623    0.8681      1358
#
#           accuracy                         0.9531      8741
#          macro avg     0.9405    0.9157    0.9278      8741
#       weighted avg     0.9528    0.9531    0.9529      8741
