# %%
#Cell 1

import os
import shutil
import zipfile
import warnings
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
from google.colab import drive

warnings.filterwarnings('ignore')
print("Imports successful.")
# Out:
# Imports successful.

# %%
#Cell 2

GDRIVE_ZIP_PATH = '/content/drive/MyDrive/AD_Dataset_compressed.zip'
LOCAL_ZIP_PATH = '/content/Data.zip'
LOCAL_UNZIP_DIR = '/content/Data'
DATA_DIR = '/content/Data/AD Datasets/Data'

IMG_SIZE = (224, 224)
BATCH_SIZE = 128
NUM_CLASSES = 4
EPOCHS = 50
LEARNING_RATE = 1e-4
SEED = 42
BEST_MODEL_SAVE_PATH = 'resnet50_best_model.keras'
AUTOTUNE = tf.data.AUTOTUNE

print("Configuration parameters set.")
# Out:
# Configuration parameters set.

# %%
# Cell 3: Mount Google Drive & Extract Dataset

drive.mount('/content/drive', force_remount=True)

if not os.path.exists(GDRIVE_ZIP_PATH):
    raise FileNotFoundError(f"Zip file not found at {GDRIVE_ZIP_PATH}")

shutil.copyfile(GDRIVE_ZIP_PATH, LOCAL_ZIP_PATH)

if os.path.exists(LOCAL_UNZIP_DIR):
    shutil.rmtree(LOCAL_UNZIP_DIR)
os.makedirs(LOCAL_UNZIP_DIR)

with zipfile.ZipFile(LOCAL_ZIP_PATH, 'r') as z:
    z.extractall(LOCAL_UNZIP_DIR)

if not os.path.isdir(DATA_DIR):
    raise FileNotFoundError(f"Expected data directory not found at {DATA_DIR}")

print("Dataset successfully extracted.")
# Out:
# Mounted at /content/drive
# Dataset successfully extracted.

# %%
#Cell 4:  Load Dataset & Split (80/10/10)


full_dataset = image_dataset_from_directory(
    DATA_DIR,
    label_mode='int',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

class_names = full_dataset.class_names
print("Classes:", class_names)

total_batches = tf.data.experimental.cardinality(full_dataset).numpy()
train_batches = int(total_batches * 0.8)
val_batches = int(total_batches * 0.1)
test_batches = total_batches - train_batches - val_batches

if val_batches == 0 and total_batches > train_batches:
    val_batches = 1
if test_batches == 0 and total_batches > train_batches + val_batches:
    test_batches = 1
train_batches = total_batches - val_batches - test_batches

train_dataset = full_dataset.take(train_batches)
val_and_test = full_dataset.skip(train_batches)
val_dataset = val_and_test.take(val_batches)
test_dataset = val_and_test.skip(val_batches)

print(f"Total batches: {total_batches}; train: {train_batches}; val: {val_batches}; test: {test_batches}")
# Out:
# Found 86437 files belonging to 4 classes.
# Classes: ['Mild Dementia', 'Moderate Dementia', 'Non Demented', 'Very mild Dementia']
# Total batches: 676; train: 540; val: 67; test: 69

# %%
# Cell 5: Class Weights, Caching, and Augmentation


train_label_list = []
for _, lbl in train_dataset:
    train_label_list.extend(lbl.numpy())
train_label_array = np.array(train_label_list)

unique_classes = np.unique(train_label_array)
weights = compute_class_weight('balanced', classes=unique_classes, y=train_label_array)
class_weight_dict = {int(c): float(w) for c, w in zip(unique_classes, weights)}
print("Class weights:", class_weight_dict)

train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.15),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomContrast(0.15),
])

print("Augmentation and caching configured.")
# Out:
# Class weights: {0: 4.3680485338725985, 1: 45.23560209424084, 2: 0.32106426859404325, 3: 1.5764984946628957}
# Augmentation and caching configured.

# %%
#Cell 6

import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model

# --- Define Focal Loss ---
def focal_loss_fn(alpha=0.25, gamma=2.5):
    def focal_loss(y_true, y_pred):
        y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=NUM_CLASSES)
        y_pred = tf.clip_by_value(y_pred, 1e-8, 1.0 - 1e-8)
        cross_entropy = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        loss = tf.reduce_sum(weight * cross_entropy, axis=1)
        return tf.reduce_mean(loss)
    return focal_loss

# --- Base Model (Frozen) ---
base_model = ResNet50(
    weights= None,
    include_top=False,
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)
base_model.trainable = True  # keep frozen for transfer learning

# --- Build Custom Head ---
inputs = tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = data_augmentation(inputs)
x = tf.keras.applications.resnet50.preprocess_input(x)
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)

x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(1024 * 2, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(1024 * 4, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(1024 * 2, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(256, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(10, activation='relu')(x)

outputs = Dense(NUM_CLASSES, activation='softmax')(x)
model = Model(inputs, outputs)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 224, 224,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 224, 224,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 7, 7,      │ 23,587,712 │ add[0][0]         │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1024)      │  2,098,176 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1024)      │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 2048)      │  2,099,200 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 2048)      │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4096)      │  8,392,704 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 4096)      │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 2048)      │  8,390,656 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 2048)      │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1024)      │  2,098,176 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 1024)      │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │    262,400 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 256)       │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 10)        │      2,570 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 4)         │         44 │ dense_6[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 46,931,638 (179.03 MB)
#  Trainable params: 46,878,518 (178.83 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
# --- Recompute class weights from training dataset ---
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

print("Recomputing class weights...")

# Collect labels from the training dataset
train_labels = []
for _, labels in train_dataset:
    train_labels.extend(labels.numpy())
train_labels = np.array(train_labels)

# Compute balanced class weights
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_labels),
    y=train_labels
)

# Map weights to each class index
class_weight_dict_mapped = {int(cls): float(w) for cls, w in zip(np.unique(train_labels), class_weights_array)}

print("Computed class weights:", class_weight_dict_mapped)
# Out:
# Recomputing class weights...
# Computed class weights: {0: 4.35374149659864, 1: 45.354330708661415, 2: 0.3210463733650416, 3: 1.578658870820391}

# %%
#Cell 7
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# --- Compile Model with Focal Loss ---
optimizer = Adam(learning_rate=1e-5)
model.compile(optimizer=optimizer, loss=focal_loss_fn(alpha=0.25, gamma=2.5), metrics=['accuracy'])

# --- Checkpoint (monitor val_loss) ---
checkpoint = ModelCheckpoint(
    filepath=BEST_MODEL_SAVE_PATH,
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# --- Early Stopping ---
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# --- Train the Model ---
EPOCHS = 50
print(f"\n--- Starting Model Training ({EPOCHS} Epochs) ---")
print(f"Best model will be saved to {BEST_MODEL_SAVE_PATH}")

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    class_weight=class_weight_dict_mapped,
    callbacks=[checkpoint]
)

print("\n--- Training Complete ---")

model.save('/content/drive/MyDrive/resnet50_best_model.keras')
# Out:
# --- Starting Model Training (50 Epochs) ---
# Best model will be saved to resnet50_best_model.keras
# Epoch 1/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7706 - loss: 0.0732
# Epoch 1: val_loss improved from inf to 0.06280, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 244s 370ms/step - accuracy: 0.7706 - loss: 0.0732 - val_accuracy: 0.7695 - val_loss: 0.0628
# Epoch 2/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7807 - loss: 0.0632
# Epoch 2: val_loss did not improve from 0.06280
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.7807 - loss: 0.0632 - val_accuracy: 0.7695 - val_loss: 0.0667
# Epoch 3/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7807 - loss: 0.0560
# Epoch 3: val_loss did not improve from 0.06280
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.7807 - loss: 0.0560 - val_accuracy: 0.7217 - val_loss: 0.0645
# Epoch 4/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7807 - loss: 0.0515
# Epoch 4: val_loss improved from 0.06280 to 0.06060, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.7807 - loss: 0.0515 - val_accuracy: 0.7201 - val_loss: 0.0606
# Epoch 5/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7834 - loss: 0.0499
# Epoch 5: val_loss improved from 0.06060 to 0.06012, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 344ms/step - accuracy: 0.7834 - loss: 0.0499 - val_accuracy: 0.7086 - val_loss: 0.0601
# Epoch 6/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7823 - loss: 0.0483
# Epoch 6: val_loss improved from 0.06012 to 0.05166, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.7823 - loss: 0.0483 - val_accuracy: 0.7535 - val_loss: 0.0517
# Epoch 7/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7856 - loss: 0.0469
# Epoch 7: val_loss improved from 0.05166 to 0.04789, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.7856 - loss: 0.0469 - val_accuracy: 0.7641 - val_loss: 0.0479
# Epoch 8/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7850 - loss: 0.0462
# Epoch 8: val_loss did not improve from 0.04789
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.7850 - loss: 0.0462 - val_accuracy: 0.7456 - val_loss: 0.0517
# Epoch 9/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7899 - loss: 0.0449
# Epoch 9: val_loss did not improve from 0.04789
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.7899 - loss: 0.0449 - val_accuracy: 0.7310 - val_loss: 0.0569
# Epoch 10/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7905 - loss: 0.0435
# Epoch 10: val_loss did not improve from 0.04789
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.7905 - loss: 0.0435 - val_accuracy: 0.7543 - val_loss: 0.0485
# Epoch 11/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7899 - loss: 0.0425
# Epoch 11: val_loss did not improve from 0.04789
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.7899 - loss: 0.0425 - val_accuracy: 0.7415 - val_loss: 0.0516
# Epoch 12/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7933 - loss: 0.0412
# Epoch 12: val_loss improved from 0.04789 to 0.04332, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.7933 - loss: 0.0412 - val_accuracy: 0.7761 - val_loss: 0.0433
# Epoch 13/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7945 - loss: 0.0397
# Epoch 13: val_loss did not improve from 0.04332
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.7945 - loss: 0.0397 - val_accuracy: 0.7367 - val_loss: 0.0495
# Epoch 14/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7979 - loss: 0.0389
# Epoch 14: val_loss improved from 0.04332 to 0.03733, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.7979 - loss: 0.0389 - val_accuracy: 0.7922 - val_loss: 0.0373
# Epoch 15/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7998 - loss: 0.0373
# Epoch 15: val_loss did not improve from 0.03733
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.7998 - loss: 0.0373 - val_accuracy: 0.7767 - val_loss: 0.0402
# Epoch 16/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8063 - loss: 0.0362
# Epoch 16: val_loss did not improve from 0.03733
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8063 - loss: 0.0362 - val_accuracy: 0.7708 - val_loss: 0.0423
# Epoch 17/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8088 - loss: 0.0352
# Epoch 17: val_loss did not improve from 0.03733
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.8088 - loss: 0.0352 - val_accuracy: 0.7569 - val_loss: 0.0461
# Epoch 18/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8144 - loss: 0.0343
# Epoch 18: val_loss improved from 0.03733 to 0.03725, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.8144 - loss: 0.0343 - val_accuracy: 0.7885 - val_loss: 0.0373
# Epoch 19/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8146 - loss: 0.0336
# Epoch 19: val_loss did not improve from 0.03725
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.8146 - loss: 0.0336 - val_accuracy: 0.7267 - val_loss: 0.0473
# Epoch 20/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8207 - loss: 0.0318
# Epoch 20: val_loss did not improve from 0.03725
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.8207 - loss: 0.0318 - val_accuracy: 0.7761 - val_loss: 0.0379
# Epoch 21/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8238 - loss: 0.0309
# Epoch 21: val_loss did not improve from 0.03725
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.8238 - loss: 0.0309 - val_accuracy: 0.7655 - val_loss: 0.0441
# Epoch 22/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8283 - loss: 0.0301
# Epoch 22: val_loss improved from 0.03725 to 0.03570, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 186s 345ms/step - accuracy: 0.8283 - loss: 0.0301 - val_accuracy: 0.7886 - val_loss: 0.0357
# Epoch 23/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8295 - loss: 0.0290
# Epoch 23: val_loss improved from 0.03570 to 0.02983, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.8295 - loss: 0.0290 - val_accuracy: 0.8256 - val_loss: 0.0298
# Epoch 24/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8339 - loss: 0.0282
# Epoch 24: val_loss did not improve from 0.02983
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8339 - loss: 0.0282 - val_accuracy: 0.8125 - val_loss: 0.0364
# Epoch 25/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8379 - loss: 0.0272
# Epoch 25: val_loss did not improve from 0.02983
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8379 - loss: 0.0272 - val_accuracy: 0.7954 - val_loss: 0.0349
# Epoch 26/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8428 - loss: 0.0265
# Epoch 26: val_loss did not improve from 0.02983
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8428 - loss: 0.0265 - val_accuracy: 0.7755 - val_loss: 0.0433
# Epoch 27/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8434 - loss: 0.0256
# Epoch 27: val_loss improved from 0.02983 to 0.02545, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.8434 - loss: 0.0256 - val_accuracy: 0.8406 - val_loss: 0.0255
# Epoch 28/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8474 - loss: 0.0248
# Epoch 28: val_loss did not improve from 0.02545
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8474 - loss: 0.0248 - val_accuracy: 0.8126 - val_loss: 0.0340
# Epoch 29/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8517 - loss: 0.0234
# Epoch 29: val_loss did not improve from 0.02545
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8516 - loss: 0.0234 - val_accuracy: 0.8196 - val_loss: 0.0308
# Epoch 30/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8576 - loss: 0.0226
# Epoch 30: val_loss improved from 0.02545 to 0.02422, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.8576 - loss: 0.0226 - val_accuracy: 0.8415 - val_loss: 0.0242
# Epoch 31/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8587 - loss: 0.0222
# Epoch 31: val_loss improved from 0.02422 to 0.02031, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 187s 347ms/step - accuracy: 0.8587 - loss: 0.0222 - val_accuracy: 0.8600 - val_loss: 0.0203
# Epoch 32/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8631 - loss: 0.0213
# Epoch 32: val_loss did not improve from 0.02031
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.8631 - loss: 0.0213 - val_accuracy: 0.8652 - val_loss: 0.0220
# Epoch 33/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8645 - loss: 0.0209
# Epoch 33: val_loss did not improve from 0.02031
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.8645 - loss: 0.0209 - val_accuracy: 0.8582 - val_loss: 0.0238
# Epoch 34/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8734 - loss: 0.0193
# Epoch 34: val_loss did not improve from 0.02031
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.8734 - loss: 0.0193 - val_accuracy: 0.8421 - val_loss: 0.0236
# Epoch 35/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8760 - loss: 0.0190
# Epoch 35: val_loss improved from 0.02031 to 0.01977, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.8760 - loss: 0.0190 - val_accuracy: 0.8727 - val_loss: 0.0198
# Epoch 36/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8795 - loss: 0.0180
# Epoch 36: val_loss improved from 0.01977 to 0.01776, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.8795 - loss: 0.0180 - val_accuracy: 0.8779 - val_loss: 0.0178
# Epoch 37/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8853 - loss: 0.0173
# Epoch 37: val_loss did not improve from 0.01776
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8853 - loss: 0.0173 - val_accuracy: 0.8243 - val_loss: 0.0412
# Epoch 38/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8881 - loss: 0.0167
# Epoch 38: val_loss improved from 0.01776 to 0.01666, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.8881 - loss: 0.0167 - val_accuracy: 0.8847 - val_loss: 0.0167
# Epoch 39/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8924 - loss: 0.0158
# Epoch 39: val_loss improved from 0.01666 to 0.01606, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 185s 343ms/step - accuracy: 0.8924 - loss: 0.0158 - val_accuracy: 0.8886 - val_loss: 0.0161
# Epoch 40/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8965 - loss: 0.0153
# Epoch 40: val_loss did not improve from 0.01606
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.8965 - loss: 0.0153 - val_accuracy: 0.8841 - val_loss: 0.0181
# Epoch 41/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9017 - loss: 0.0143
# Epoch 41: val_loss did not improve from 0.01606
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.9017 - loss: 0.0143 - val_accuracy: 0.8723 - val_loss: 0.0185
# Epoch 42/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9065 - loss: 0.0135
# Epoch 42: val_loss did not improve from 0.01606
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.9065 - loss: 0.0135 - val_accuracy: 0.8499 - val_loss: 0.0241
# Epoch 43/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9084 - loss: 0.0136
# Epoch 43: val_loss did not improve from 0.01606
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.9084 - loss: 0.0136 - val_accuracy: 0.8414 - val_loss: 0.0436
# Epoch 44/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9117 - loss: 0.0128
# Epoch 44: val_loss did not improve from 0.01606
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.9117 - loss: 0.0128 - val_accuracy: 0.8919 - val_loss: 0.0164
# Epoch 45/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9158 - loss: 0.0118
# Epoch 45: val_loss did not improve from 0.01606
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9158 - loss: 0.0118 - val_accuracy: 0.8691 - val_loss: 0.0193
# Epoch 46/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9168 - loss: 0.0118
# Epoch 46: val_loss improved from 0.01606 to 0.01281, saving model to resnet50_best_model.keras
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 188s 347ms/step - accuracy: 0.9168 - loss: 0.0118 - val_accuracy: 0.9107 - val_loss: 0.0128
# Epoch 47/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9207 - loss: 0.0112
# Epoch 47: val_loss did not improve from 0.01281
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 339ms/step - accuracy: 0.9207 - loss: 0.0112 - val_accuracy: 0.8639 - val_loss: 0.0333
# Epoch 48/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9257 - loss: 0.0106
# Epoch 48: val_loss did not improve from 0.01281
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.9257 - loss: 0.0106 - val_accuracy: 0.9094 - val_loss: 0.0137
# Epoch 49/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9281 - loss: 0.0104
# Epoch 49: val_loss did not improve from 0.01281
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.9281 - loss: 0.0104 - val_accuracy: 0.9142 - val_loss: 0.0141
# Epoch 50/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9320 - loss: 0.0099
# Epoch 50: val_loss did not improve from 0.01281
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 183s 338ms/step - accuracy: 0.9320 - loss: 0.0099 - val_accuracy: 0.8709 - val_loss: 0.0255
#
# --- Training Complete ---

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- Load Best Model ---
best_model = tf.keras.models.load_model(BEST_MODEL_SAVE_PATH, custom_objects={'focal_loss': focal_loss_fn()})

# --- Evaluate ---
train_loss, train_acc = best_model.evaluate(train_dataset)
val_loss, val_acc = best_model.evaluate(val_dataset)
test_loss, test_acc = best_model.evaluate(test_dataset)

print("\n--- Final Overall Performance ---")
print(f"Training Accuracy:   {train_acc:.4f}")
print(f"Validation Accuracy: {val_acc:.4f}")
print(f"Test Accuracy:       {test_acc:.4f}")
print(f"Training Loss:   {train_loss:.4f}")
print(f"Validation Loss: {val_loss:.4f}")
print(f"Test Loss:       {test_loss:.4f}")

# --- Predict and Metrics ---
y_true = np.concatenate([y for _, y in test_dataset], axis=0)
y_pred_probs = best_model.predict(test_dataset)
y_pred = np.argmax(y_pred_probs, axis=1)

print("\n--- Per-Class Metrics (Test Set) ---")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# --- Plot Learning Curves ---
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy Curve')

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss Curve')

plt.show()
# Out:
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 41s 70ms/step - accuracy: 0.9157 - loss: 0.0121
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9114 - loss: 0.0119
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 27s 96ms/step - accuracy: 0.9153 - loss: 0.0117
#
# --- Final Overall Performance ---
# Training Accuracy:   0.9143
# Validation Accuracy: 0.9107
# Test Accuracy:       0.9150
# Training Loss:   0.0122
# Validation Loss: 0.0128
# Test Loss:       0.0120
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 92ms/step
#
# --- Per-Class Metrics (Test Set) ---
#                     precision    recall  f1-score   support
#
#      Mild Dementia     0.6773    0.9368    0.7862       522
#  Moderate Dementia     0.9455    1.0000    0.9720        52
#       Non Demented     0.9514    0.9570    0.9542      6809
# Very mild Dementia     0.8439    0.6929    0.7610      1358
#
#           accuracy                         0.9150      8741
#          macro avg     0.8545    0.8967    0.8683      8741
#       weighted avg     0.9183    0.9150    0.9142      8741
